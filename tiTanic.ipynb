# %% [markdown]
# # Data Visualisation of the Titanic Dataset

# %% [markdown]
# ## Importing Packages and Dataset

# %%
#Import packages
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

#Reset seaborn colour palette to be colourblind friendly
sns.reset_orig()
my_palette = sns.color_palette('colorblind')

# %%
#Import the csv file dataset
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      Passenger_Id  Survived  Class  \
# 0               1         0      3
# 1               2         1      1
# 2               3         1      3
# 3               4         1      1
# 4               5         0      3
# ..            ...       ...    ...
# 709           886         0      3
# 710           887         0      2
# 711           888         1      1
# 712           890         1      1
# 713           891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 709               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 710                              Montvila, Rev. Juozas    male  27.0      0
# 711                       Graham, Miss. Margaret Edith  female  19.0      0
# 712                              Behr, Mr. Karl Howell    male  26.0      0
# 713                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 709      5            382652  29.1250        Q
# 710      0            211536  13.0000        S
# 711      0            112053  30.0000        S
# 712      0            111369  30.0000        C
# 713      0            370376   7.7500        Q
#
# [714 rows x 11 columns]

# %%
#Dataset information
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Passenger_Id  714 non-null    int64
#  1   Survived      714 non-null    int64
#  2   Class         714 non-null    int64
#  3   Name          714 non-null    object
#  4   Sex           714 non-null    object
#  5   Age           714 non-null    float64
#  6   SibSp         714 non-null    int64
#  7   Parch         714 non-null    int64
#  8   Ticket        714 non-null    object
#  9   Fare          714 non-null    float64
#  10  Embarked      712 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 61.5+ KB

# %%
#Show the data types
titanic.dtypes
# Out:
# Passenger_Id      int64
# Survived          int64
# Class             int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Embarked         object
# dtype: object

# %%
#Show unique variable elements
titanic.Embarked.unique
# Out:
# <bound method Series.unique of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 709    Q
# 710    S
# 711    S
# 712    C
# 713    Q
# Name: Embarked, Length: 714, dtype: object>

# %%
#Count the unique elements in the variable
titanic.Embarked.value_counts()
# Out:
# Embarked
# S    554
# C    130
# Q     28
# Name: count, dtype: int64

# %%
titanic.Sex.value_counts()
# Out:
# Sex
# male      453
# female    261
# Name: count, dtype: int64

# %%
#Check for missing values
titanic.isna().sum()
# Out:
# Passenger_Id    0
# Survived        0
# Class           0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        2
# dtype: int64

# %%
#Change variable type
titanic.Class = titanic.Class.astype(object)

# %%
#Describe the dataset
titanic.describe()
# Out:
#        Passenger_Id    Survived         Age       SibSp       Parch  \
# count    714.000000  714.000000  714.000000  714.000000  714.000000
# mean     448.582633    0.406162   29.712185    0.512605    0.431373
# std      259.119524    0.491460   14.528740    0.929783    0.853289
# min        1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      222.250000    0.000000   20.250000    0.000000    0.000000
# 50%      445.000000    0.000000   28.000000    0.000000    0.000000
# 75%      677.750000    1.000000   38.000000    1.000000    1.000000
# max      891.000000    1.000000   80.000000    5.000000    6.000000
#
#              Fare
# count  714.000000
# mean    34.694514
# std     52.918930
# min      0.000000
# 25%      8.050000
# 50%     15.741700
# 75%     33.375000
# max    512.329200

# %%
#Create a new column for family containing parents, children and the passanger themsleves
titanic['Family size'] = titanic['SibSp'] + titanic['Parch'] + 1

titanic
#To see the last rows of the table use titanic.tail() 
#To see the first few rows of the use titanic.head()
# Out:
#      Passenger_Id  Survived Class  \
# 0               1         0     3
# 1               2         1     1
# 2               3         1     3
# 3               4         1     1
# 4               5         0     3
# ..            ...       ...   ...
# 709           886         0     3
# 710           887         0     2
# 711           888         1     1
# 712           890         1     1
# 713           891         0     3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 709               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 710                              Montvila, Rev. Juozas    male  27.0      0
# 711                       Graham, Miss. Margaret Edith  female  19.0      0
# 712                              Behr, Mr. Karl Howell    male  26.0      0
# 713                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked  Family size
# 0        0         A/5 21171   7.2500        S            2
# 1        0          PC 17599  71.2833        C            2
# 2        0  STON/O2. 3101282   7.9250        S            1
# 3        0            113803  53.1000        S            2
# 4        0            373450   8.0500        S            1
# ..     ...               ...      ...      ...          ...
# 709      5            382652  29.1250        Q            6
# 710      0            211536  13.0000        S            1
# 711      0            112053  30.0000        S            1
# 712      0            111369  30.0000        C            1
# 713      0            370376   7.7500        Q            1
#
# [714 rows x 12 columns]

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### Bar Plots

# %%
pd.DataFrame(titanic[['Sex', 'Survived', 'Class']].value_counts())
# Out:
#                        count
# Sex    Survived Class
# male   0        3        215
#                 2         84
# female 1        1         82
#                 2         68
# male   0        1         61
# female 0        3         55
#        1        3         47
# male   1        1         40
#                 3         38
#                 2         15
# female 0        2          6
#                 1          3

# %%
#Bar plots of sex, class and survival relationship
fig, ax = plt.subplots(1,2, figsize=(15,4))
ax[0].bar(titanic["Sex"], titanic["Class"], alpha = 0.6, width = 0.5)

ax[0].set_ylabel('Class')
ax[0].set_xlabel('Sex')
ax[0].title.set_text("Class per Gender")
